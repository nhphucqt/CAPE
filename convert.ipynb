# %%
import msgpack
import json
from pathlib import Path

# %%
result_dir = Path("result_records")
output_dir = Path("result_records_msgpack")

# %%
output_dir.mkdir(exist_ok=True, parents=True)
print(list(result_dir.glob("*.json")))
for result_file in result_dir.glob("*.json"):
    output_file = (output_dir / result_file.name).with_suffix(".msgpack")
    if output_file.exists():
        print(f"Skipping {result_file} as {output_file} already exists")
        continue
    with open(result_file, "r") as f:
        data = json.load(f)
    with open(output_file, "wb") as f:
        msgpack.pack(data, f)
# Out:
# [PosixPath('result_records/result_voronoi_ref_edgecape_s1_10_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_ref_graphcape_s1_20_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s4_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_capeformer_s4_5_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_ref_graphcape_s1_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_capeformer_s1_5_1_300k_prototype_ori.json'), PosixPath('result_records/error_result_voronoi_ref_edgecape_s4_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_graphcape_s4_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_ref_graphcape_s1_10_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_ref_edgecape_s1_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_1_1_600k_prototype.json'), PosixPath('result_records/error_result_voronoi_ref_edgecape_s1_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_10_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_graphcape_s1_20_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_ref_edgecape_s1_20_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_3_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_graphcape_s1_10_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_capeformer_s1_5_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_edgecape_s4_3_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_edgecape_s1_50_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_capeformer_s4_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_3_1_300k.json'), PosixPath('result_records/result_voronoi_ref_graphcape_s4_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_3_1_10k.json'), PosixPath('result_records/result_voronoi_edgecape_s1_50_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_ref_graphcape_s1_50_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_ref_capeformer_s1_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_10_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_graphcape_s1_5_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_ref_edgecape_s4_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s4_5_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_edgecape_s1_3_1_10k_prototype.json'), PosixPath('result_records/result_voronoi_ref_edgecape_s1_50_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_5_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_graphcape_s4_5_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_edgecape_s1_20_1_300k_prototype.json'), PosixPath('result_records/result_voronoi_ref_capeformer_s4_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_20_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_graphcape_s1_5_1_300k_prototype_ori.json'), PosixPath('result_records/result_voronoi_edgecape_s1_5_1_300k_prototype_ori.json')]
